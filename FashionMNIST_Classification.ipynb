# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import random
sns.set_style("whitegrid")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
fashion_train_df = pd.read_csv('/content/drive/My Drive/fashion-mnist_train.csv',sep=',')
fashion_test_df = pd.read_csv('/content/drive/My Drive/fashion-mnist_test.csv', sep = ',')

# %%
#Shape of training data
fashion_train_df.shape
# Out:
# (60000, 785)

# %%
#Shape of test data
fashion_test_df.shape
# Out:
# (10000, 785)

# %%
train = np.array(fashion_train_df, dtype = 'float32')
test = np.array(fashion_test_df, dtype='float32')

# %%
class_names = ['T_shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
#See a random image for class label verification
i = random.randint(1,60000)
plt.imshow(train[i,1:].reshape((28,28))) 

plt.imshow(train[i,1:].reshape((28,28))) 
label_index = fashion_train_df["label"][i]
plt.title(f"{class_names[label_index]}")
plt.axis('off')
# Out:
# (-0.5, 27.5, 27.5, -0.5)

# %%
#Label of the random image
label = train[i,0]
label
# Out:
# 7.0

# %%
# Define the dimensions of the plot grid 
W_grid = 15
L_grid = 15
fig, axes = plt.subplots(L_grid, W_grid, figsize = (17,17))
axes = axes.ravel() # flaten the 15 x 15 matrix into 225 array
n_train = len(train) # get the length of the train dataset
# Select a random number from 0 to n_train
for i in np.arange(0, W_grid * L_grid): # create evenly spaces variables 
    # Select a random number
    index = np.random.randint(0, n_train)
    # read and display an image with the selected index    
    axes[i].imshow( train[index,1:].reshape((28,28)) )
    label_index = int(train[index,0])
    axes[i].set_title(class_names[label_index], fontsize = 8)
    axes[i].axis('off')
plt.subplots_adjust(hspace=0.4)

# %%
# Prepare the training and testing dataset 
X_train = train[:, 1:] / 255
y_train = train[:, 0]

X_test = test[:, 1:] / 255
y_test = test[:,0]

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i].reshape((28,28)), cmap=plt.cm.binary)
    label_index = int(y_train[i])
    plt.title(class_names[label_index])
plt.show()

# %%
#Split the training and test sets
from sklearn.model_selection import train_test_split
X_train, X_validate, y_train, y_validate = train_test_split(X_train, y_train, test_size = 0.2, random_state = 12345)

print(X_train.shape)
print(y_train.shape)
# Out:
# (48000, 784)
# (48000,)

# %%
# Unpack the training and test tuple
X_train = X_train.reshape(X_train.shape[0], *(28, 28, 1))
X_test = X_test.reshape(X_test.shape[0], *(28, 28, 1))
X_validate = X_validate.reshape(X_validate.shape[0], *(28, 28, 1))

print(X_train.shape)
print(y_train.shape)
print(X_validate.shape)
# Out:
# (48000, 28, 28, 1)
# (48000,)
# (12000, 28, 28, 1)

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.optimizers import Adam
from keras.callbacks import TensorBoard
# Out:
# Using TensorFlow backend.

# %%
cnn_model = Sequential()

cnn_model.add(Conv2D(32, (3, 3), input_shape = (28,28,1), activation='relu'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
cnn_model.add(Dropout(0.25))

cnn_model.add(Conv2D(64, (3, 3), input_shape = (28,28,1), activation='relu'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
cnn_model.add(Dropout(0.25))

cnn_model.add(Conv2D(128, (3, 3), input_shape = (28,28,1), activation='relu'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
cnn_model.add(Dropout(0.25))

cnn_model.add(Flatten())
cnn_model.add(Dense(units = 512, activation = 'relu'))
cnn_model.add(Dropout(0.25))
cnn_model.add(Dense(units = 10, activation = 'softmax'))

# %%
cnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               66048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 163,850
# Trainable params: 163,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compiling
cnn_model.compile(loss ='sparse_categorical_crossentropy', optimizer='adam' ,metrics =['accuracy'])

# %%
#Training the CNN model
history = cnn_model.fit(X_train, y_train, batch_size = 512, epochs = 200, verbose = 1, validation_data = (X_validate, y_validate))
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/200
# 48000/48000 [==============================] - 3s 66us/step - loss: 0.5342 - accuracy: 0.8035 - val_loss: 0.4660 - val_accuracy: 0.8267
# Epoch 2/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.5007 - accuracy: 0.8163 - val_loss: 0.4228 - val_accuracy: 0.8438
# Epoch 3/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.4742 - accuracy: 0.8273 - val_loss: 0.4042 - val_accuracy: 0.8518
# Epoch 4/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.4479 - accuracy: 0.8374 - val_loss: 0.3828 - val_accuracy: 0.8588
# Epoch 5/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.4326 - accuracy: 0.8418 - val_loss: 0.3740 - val_accuracy: 0.8612
# Epoch 6/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.4170 - accuracy: 0.8493 - val_loss: 0.3564 - val_accuracy: 0.8698
# Epoch 7/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.4046 - accuracy: 0.8523 - val_loss: 0.3555 - val_accuracy: 0.8695
# Epoch 8/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.3951 - accuracy: 0.8545 - val_loss: 0.3433 - val_accuracy: 0.8742
# Epoch 9/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.3862 - accuracy: 0.8579 - val_loss: 0.3405 - val_accuracy: 0.8767
# Epoch 10/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.3712 - accuracy: 0.8645 - val_loss: 0.3232 - val_accuracy: 0.8804
# Epoch 11/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.3671 - accuracy: 0.8666 - val_loss: 0.3178 - val_accuracy: 0.8820
# Epoch 12/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.3569 - accuracy: 0.8691 - val_loss: 0.3148 - val_accuracy: 0.8824
# Epoch 13/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.3500 - accuracy: 0.8708 - val_loss: 0.3116 - val_accuracy: 0.8861
# Epoch 14/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.3440 - accuracy: 0.8740 - val_loss: 0.3091 - val_accuracy: 0.8843
# Epoch 15/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.3353 - accuracy: 0.8780 - val_loss: 0.2957 - val_accuracy: 0.8904
# Epoch 16/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.3353 - accuracy: 0.8771 - val_loss: 0.3098 - val_accuracy: 0.8846
# Epoch 17/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.3287 - accuracy: 0.8796 - val_loss: 0.2956 - val_accuracy: 0.8907
# Epoch 18/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.3243 - accuracy: 0.8806 - val_loss: 0.2931 - val_accuracy: 0.8898
# Epoch 19/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.3206 - accuracy: 0.8821 - val_loss: 0.2898 - val_accuracy: 0.8922
# Epoch 20/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.3125 - accuracy: 0.8833 - val_loss: 0.2858 - val_accuracy: 0.8940
# Epoch 21/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.3108 - accuracy: 0.8854 - val_loss: 0.2780 - val_accuracy: 0.8967
# Epoch 22/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.3078 - accuracy: 0.8876 - val_loss: 0.2772 - val_accuracy: 0.8969
# Epoch 23/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.3016 - accuracy: 0.8880 - val_loss: 0.2880 - val_accuracy: 0.8904
# Epoch 24/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2987 - accuracy: 0.8895 - val_loss: 0.2776 - val_accuracy: 0.8948
# Epoch 25/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2954 - accuracy: 0.8911 - val_loss: 0.2767 - val_accuracy: 0.8942
# Epoch 26/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2939 - accuracy: 0.8909 - val_loss: 0.2746 - val_accuracy: 0.8980
# Epoch 27/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2894 - accuracy: 0.8940 - val_loss: 0.2710 - val_accuracy: 0.8982
# Epoch 28/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2861 - accuracy: 0.8962 - val_loss: 0.2659 - val_accuracy: 0.9010
# Epoch 29/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2834 - accuracy: 0.8964 - val_loss: 0.2647 - val_accuracy: 0.9005
# Epoch 30/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2830 - accuracy: 0.8947 - val_loss: 0.2648 - val_accuracy: 0.9007
# Epoch 31/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2817 - accuracy: 0.8958 - val_loss: 0.2696 - val_accuracy: 0.8997
# Epoch 32/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2783 - accuracy: 0.8978 - val_loss: 0.2645 - val_accuracy: 0.9001
# Epoch 33/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2755 - accuracy: 0.8961 - val_loss: 0.2628 - val_accuracy: 0.9018
# Epoch 34/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2764 - accuracy: 0.8970 - val_loss: 0.2641 - val_accuracy: 0.9006
# Epoch 35/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2743 - accuracy: 0.8986 - val_loss: 0.2624 - val_accuracy: 0.9023
# Epoch 36/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2705 - accuracy: 0.8981 - val_loss: 0.2694 - val_accuracy: 0.8999
# Epoch 37/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2724 - accuracy: 0.8986 - val_loss: 0.2606 - val_accuracy: 0.9020
# Epoch 38/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2653 - accuracy: 0.9013 - val_loss: 0.2575 - val_accuracy: 0.9060
# Epoch 39/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2669 - accuracy: 0.9004 - val_loss: 0.2559 - val_accuracy: 0.9016
# Epoch 40/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2627 - accuracy: 0.9022 - val_loss: 0.2725 - val_accuracy: 0.8991
# Epoch 41/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2618 - accuracy: 0.9021 - val_loss: 0.2642 - val_accuracy: 0.9021
# Epoch 42/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2581 - accuracy: 0.9038 - val_loss: 0.2556 - val_accuracy: 0.9054
# Epoch 43/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2559 - accuracy: 0.9052 - val_loss: 0.2570 - val_accuracy: 0.9041
# Epoch 44/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2541 - accuracy: 0.9047 - val_loss: 0.2488 - val_accuracy: 0.9044
# Epoch 45/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2546 - accuracy: 0.9049 - val_loss: 0.2506 - val_accuracy: 0.9065
# Epoch 46/200
# 48000/48000 [==============================] - 3s 64us/step - loss: 0.2552 - accuracy: 0.9050 - val_loss: 0.2514 - val_accuracy: 0.9046
# Epoch 47/200
# 48000/48000 [==============================] - 3s 64us/step - loss: 0.2526 - accuracy: 0.9070 - val_loss: 0.2550 - val_accuracy: 0.9027
# Epoch 48/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2496 - accuracy: 0.9071 - val_loss: 0.2476 - val_accuracy: 0.9082
# Epoch 49/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2479 - accuracy: 0.9085 - val_loss: 0.2517 - val_accuracy: 0.9066
# Epoch 50/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2434 - accuracy: 0.9084 - val_loss: 0.2485 - val_accuracy: 0.9071
# Epoch 51/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2436 - accuracy: 0.9088 - val_loss: 0.2517 - val_accuracy: 0.9050
# Epoch 52/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2444 - accuracy: 0.9078 - val_loss: 0.2525 - val_accuracy: 0.9048
# Epoch 53/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2435 - accuracy: 0.9090 - val_loss: 0.2560 - val_accuracy: 0.9028
# Epoch 54/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2383 - accuracy: 0.9102 - val_loss: 0.2505 - val_accuracy: 0.9064
# Epoch 55/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2387 - accuracy: 0.9111 - val_loss: 0.2618 - val_accuracy: 0.9011
# Epoch 56/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2380 - accuracy: 0.9101 - val_loss: 0.2631 - val_accuracy: 0.9011
# Epoch 57/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2419 - accuracy: 0.9098 - val_loss: 0.2528 - val_accuracy: 0.9038
# Epoch 58/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2342 - accuracy: 0.9123 - val_loss: 0.2508 - val_accuracy: 0.9094
# Epoch 59/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2376 - accuracy: 0.9110 - val_loss: 0.2488 - val_accuracy: 0.9089
# Epoch 60/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2345 - accuracy: 0.9114 - val_loss: 0.2487 - val_accuracy: 0.9087
# Epoch 61/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2326 - accuracy: 0.9140 - val_loss: 0.2508 - val_accuracy: 0.9058
# Epoch 62/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2306 - accuracy: 0.9134 - val_loss: 0.2489 - val_accuracy: 0.9057
# Epoch 63/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2303 - accuracy: 0.9141 - val_loss: 0.2444 - val_accuracy: 0.9082
# Epoch 64/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2288 - accuracy: 0.9150 - val_loss: 0.2515 - val_accuracy: 0.9078
# Epoch 65/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2320 - accuracy: 0.9122 - val_loss: 0.2452 - val_accuracy: 0.9082
# Epoch 66/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2288 - accuracy: 0.9148 - val_loss: 0.2522 - val_accuracy: 0.9056
# Epoch 67/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2304 - accuracy: 0.9142 - val_loss: 0.2461 - val_accuracy: 0.9078
# Epoch 68/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2286 - accuracy: 0.9141 - val_loss: 0.2493 - val_accuracy: 0.9081
# Epoch 69/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2265 - accuracy: 0.9154 - val_loss: 0.2537 - val_accuracy: 0.9060
# Epoch 70/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2258 - accuracy: 0.9149 - val_loss: 0.2453 - val_accuracy: 0.9080
# Epoch 71/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2236 - accuracy: 0.9171 - val_loss: 0.2442 - val_accuracy: 0.9074
# Epoch 72/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2242 - accuracy: 0.9162 - val_loss: 0.2456 - val_accuracy: 0.9084
# Epoch 73/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2258 - accuracy: 0.9150 - val_loss: 0.2451 - val_accuracy: 0.9105
# Epoch 74/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2239 - accuracy: 0.9169 - val_loss: 0.2444 - val_accuracy: 0.9093
# Epoch 75/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2175 - accuracy: 0.9179 - val_loss: 0.2512 - val_accuracy: 0.9075
# Epoch 76/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2221 - accuracy: 0.9159 - val_loss: 0.2512 - val_accuracy: 0.9084
# Epoch 77/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2226 - accuracy: 0.9183 - val_loss: 0.2495 - val_accuracy: 0.9089
# Epoch 78/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2179 - accuracy: 0.9186 - val_loss: 0.2444 - val_accuracy: 0.9095
# Epoch 79/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2208 - accuracy: 0.9164 - val_loss: 0.2440 - val_accuracy: 0.9107
# Epoch 80/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2192 - accuracy: 0.9174 - val_loss: 0.2443 - val_accuracy: 0.9105
# Epoch 81/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2174 - accuracy: 0.9179 - val_loss: 0.2462 - val_accuracy: 0.9093
# Epoch 82/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2152 - accuracy: 0.9198 - val_loss: 0.2514 - val_accuracy: 0.9099
# Epoch 83/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2166 - accuracy: 0.9180 - val_loss: 0.2434 - val_accuracy: 0.9102
# Epoch 84/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2189 - accuracy: 0.9171 - val_loss: 0.2526 - val_accuracy: 0.9063
# Epoch 85/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2155 - accuracy: 0.9193 - val_loss: 0.2420 - val_accuracy: 0.9099
# Epoch 86/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2146 - accuracy: 0.9199 - val_loss: 0.2441 - val_accuracy: 0.9097
# Epoch 87/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2152 - accuracy: 0.9189 - val_loss: 0.2478 - val_accuracy: 0.9074
# Epoch 88/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2101 - accuracy: 0.9213 - val_loss: 0.2505 - val_accuracy: 0.9090
# Epoch 89/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2106 - accuracy: 0.9208 - val_loss: 0.2501 - val_accuracy: 0.9077
# Epoch 90/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2114 - accuracy: 0.9210 - val_loss: 0.2460 - val_accuracy: 0.9087
# Epoch 91/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2160 - accuracy: 0.9189 - val_loss: 0.2434 - val_accuracy: 0.9121
# Epoch 92/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2082 - accuracy: 0.9214 - val_loss: 0.2450 - val_accuracy: 0.9085
# Epoch 93/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2073 - accuracy: 0.9210 - val_loss: 0.2499 - val_accuracy: 0.9063
# Epoch 94/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2055 - accuracy: 0.9227 - val_loss: 0.2476 - val_accuracy: 0.9102
# Epoch 95/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2067 - accuracy: 0.9217 - val_loss: 0.2432 - val_accuracy: 0.9108
# Epoch 96/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2075 - accuracy: 0.9223 - val_loss: 0.2425 - val_accuracy: 0.9098
# Epoch 97/200
# 48000/48000 [==============================] - 3s 64us/step - loss: 0.2046 - accuracy: 0.9220 - val_loss: 0.2438 - val_accuracy: 0.9110
# Epoch 98/200
# 48000/48000 [==============================] - 3s 64us/step - loss: 0.2057 - accuracy: 0.9223 - val_loss: 0.2525 - val_accuracy: 0.9108
# Epoch 99/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2086 - accuracy: 0.9204 - val_loss: 0.2475 - val_accuracy: 0.9098
# Epoch 100/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2019 - accuracy: 0.9226 - val_loss: 0.2458 - val_accuracy: 0.9114
# Epoch 101/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2066 - accuracy: 0.9223 - val_loss: 0.2459 - val_accuracy: 0.9096
# Epoch 102/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2071 - accuracy: 0.9220 - val_loss: 0.2439 - val_accuracy: 0.9108
# Epoch 103/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2024 - accuracy: 0.9238 - val_loss: 0.2450 - val_accuracy: 0.9115
# Epoch 104/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2009 - accuracy: 0.9255 - val_loss: 0.2430 - val_accuracy: 0.9128
# Epoch 105/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1994 - accuracy: 0.9239 - val_loss: 0.2490 - val_accuracy: 0.9108
# Epoch 106/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2058 - accuracy: 0.9230 - val_loss: 0.2491 - val_accuracy: 0.9086
# Epoch 107/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2013 - accuracy: 0.9242 - val_loss: 0.2463 - val_accuracy: 0.9116
# Epoch 108/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2021 - accuracy: 0.9241 - val_loss: 0.2414 - val_accuracy: 0.9128
# Epoch 109/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2031 - accuracy: 0.9237 - val_loss: 0.2504 - val_accuracy: 0.9099
# Epoch 110/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2043 - accuracy: 0.9235 - val_loss: 0.2438 - val_accuracy: 0.9133
# Epoch 111/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.2006 - accuracy: 0.9250 - val_loss: 0.2519 - val_accuracy: 0.9104
# Epoch 112/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1997 - accuracy: 0.9249 - val_loss: 0.2516 - val_accuracy: 0.9102
# Epoch 113/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2041 - accuracy: 0.9225 - val_loss: 0.2425 - val_accuracy: 0.9117
# Epoch 114/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1971 - accuracy: 0.9254 - val_loss: 0.2528 - val_accuracy: 0.9107
# Epoch 115/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2027 - accuracy: 0.9230 - val_loss: 0.2531 - val_accuracy: 0.9086
# Epoch 116/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2026 - accuracy: 0.9224 - val_loss: 0.2435 - val_accuracy: 0.9122
# Epoch 117/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1995 - accuracy: 0.9247 - val_loss: 0.2511 - val_accuracy: 0.9120
# Epoch 118/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1995 - accuracy: 0.9249 - val_loss: 0.2508 - val_accuracy: 0.9101
# Epoch 119/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1965 - accuracy: 0.9273 - val_loss: 0.2482 - val_accuracy: 0.9128
# Epoch 120/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2004 - accuracy: 0.9253 - val_loss: 0.2454 - val_accuracy: 0.9141
# Epoch 121/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1978 - accuracy: 0.9264 - val_loss: 0.2484 - val_accuracy: 0.9125
# Epoch 122/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1971 - accuracy: 0.9253 - val_loss: 0.2450 - val_accuracy: 0.9137
# Epoch 123/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1954 - accuracy: 0.9273 - val_loss: 0.2490 - val_accuracy: 0.9111
# Epoch 124/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1970 - accuracy: 0.9252 - val_loss: 0.2469 - val_accuracy: 0.9107
# Epoch 125/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1959 - accuracy: 0.9266 - val_loss: 0.2472 - val_accuracy: 0.9110
# Epoch 126/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1950 - accuracy: 0.9270 - val_loss: 0.2453 - val_accuracy: 0.9135
# Epoch 127/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1915 - accuracy: 0.9265 - val_loss: 0.2501 - val_accuracy: 0.9100
# Epoch 128/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1940 - accuracy: 0.9271 - val_loss: 0.2499 - val_accuracy: 0.9113
# Epoch 129/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1954 - accuracy: 0.9268 - val_loss: 0.2449 - val_accuracy: 0.9122
# Epoch 130/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1947 - accuracy: 0.9264 - val_loss: 0.2422 - val_accuracy: 0.9137
# Epoch 131/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1964 - accuracy: 0.9252 - val_loss: 0.2508 - val_accuracy: 0.9103
# Epoch 132/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1904 - accuracy: 0.9281 - val_loss: 0.2469 - val_accuracy: 0.9114
# Epoch 133/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1937 - accuracy: 0.9275 - val_loss: 0.2536 - val_accuracy: 0.9114
# Epoch 134/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1918 - accuracy: 0.9286 - val_loss: 0.2441 - val_accuracy: 0.9112
# Epoch 135/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1933 - accuracy: 0.9270 - val_loss: 0.2563 - val_accuracy: 0.9091
# Epoch 136/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1907 - accuracy: 0.9285 - val_loss: 0.2470 - val_accuracy: 0.9118
# Epoch 137/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1907 - accuracy: 0.9292 - val_loss: 0.2464 - val_accuracy: 0.9107
# Epoch 138/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1908 - accuracy: 0.9283 - val_loss: 0.2538 - val_accuracy: 0.9080
# Epoch 139/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1908 - accuracy: 0.9281 - val_loss: 0.2488 - val_accuracy: 0.9108
# Epoch 140/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1895 - accuracy: 0.9281 - val_loss: 0.2532 - val_accuracy: 0.9096
# Epoch 141/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1874 - accuracy: 0.9282 - val_loss: 0.2531 - val_accuracy: 0.9117
# Epoch 142/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1921 - accuracy: 0.9279 - val_loss: 0.2519 - val_accuracy: 0.9112
# Epoch 143/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1894 - accuracy: 0.9282 - val_loss: 0.2462 - val_accuracy: 0.9118
# Epoch 144/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1893 - accuracy: 0.9303 - val_loss: 0.2536 - val_accuracy: 0.9103
# Epoch 145/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1918 - accuracy: 0.9291 - val_loss: 0.2510 - val_accuracy: 0.9102
# Epoch 146/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1874 - accuracy: 0.9288 - val_loss: 0.2543 - val_accuracy: 0.9107
# Epoch 147/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1869 - accuracy: 0.9298 - val_loss: 0.2461 - val_accuracy: 0.9117
# Epoch 148/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1900 - accuracy: 0.9277 - val_loss: 0.2455 - val_accuracy: 0.9141
# Epoch 149/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1865 - accuracy: 0.9311 - val_loss: 0.2496 - val_accuracy: 0.9118
# Epoch 150/200
# 48000/48000 [==============================] - 3s 64us/step - loss: 0.1850 - accuracy: 0.9310 - val_loss: 0.2506 - val_accuracy: 0.9140
# Epoch 151/200
# 48000/48000 [==============================] - 3s 64us/step - loss: 0.1906 - accuracy: 0.9296 - val_loss: 0.2489 - val_accuracy: 0.9125
# Epoch 152/200
# 48000/48000 [==============================] - 3s 64us/step - loss: 0.1857 - accuracy: 0.9302 - val_loss: 0.2419 - val_accuracy: 0.9118
# Epoch 153/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1854 - accuracy: 0.9302 - val_loss: 0.2450 - val_accuracy: 0.9128
# Epoch 154/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1887 - accuracy: 0.9302 - val_loss: 0.2494 - val_accuracy: 0.9115
# Epoch 155/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1845 - accuracy: 0.9299 - val_loss: 0.2464 - val_accuracy: 0.9153
# Epoch 156/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1867 - accuracy: 0.9304 - val_loss: 0.2455 - val_accuracy: 0.9150
# Epoch 157/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1825 - accuracy: 0.9306 - val_loss: 0.2436 - val_accuracy: 0.9144
# Epoch 158/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1851 - accuracy: 0.9293 - val_loss: 0.2465 - val_accuracy: 0.9127
# Epoch 159/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1824 - accuracy: 0.9313 - val_loss: 0.2522 - val_accuracy: 0.9112
# Epoch 160/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1845 - accuracy: 0.9311 - val_loss: 0.2493 - val_accuracy: 0.9107
# Epoch 161/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1862 - accuracy: 0.9291 - val_loss: 0.2477 - val_accuracy: 0.9112
# Epoch 162/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1807 - accuracy: 0.9320 - val_loss: 0.2433 - val_accuracy: 0.9139
# Epoch 163/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1826 - accuracy: 0.9312 - val_loss: 0.2515 - val_accuracy: 0.9121
# Epoch 164/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1839 - accuracy: 0.9304 - val_loss: 0.2628 - val_accuracy: 0.9075
# Epoch 165/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1845 - accuracy: 0.9309 - val_loss: 0.2481 - val_accuracy: 0.9128
# Epoch 166/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1862 - accuracy: 0.9302 - val_loss: 0.2454 - val_accuracy: 0.9142
# Epoch 167/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1831 - accuracy: 0.9315 - val_loss: 0.2470 - val_accuracy: 0.9127
# Epoch 168/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1832 - accuracy: 0.9304 - val_loss: 0.2462 - val_accuracy: 0.9134
# Epoch 169/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1796 - accuracy: 0.9320 - val_loss: 0.2457 - val_accuracy: 0.9134
# Epoch 170/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1815 - accuracy: 0.9309 - val_loss: 0.2488 - val_accuracy: 0.9118
# Epoch 171/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1806 - accuracy: 0.9305 - val_loss: 0.2544 - val_accuracy: 0.9093
# Epoch 172/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1808 - accuracy: 0.9325 - val_loss: 0.2616 - val_accuracy: 0.9072
# Epoch 173/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1795 - accuracy: 0.9320 - val_loss: 0.2470 - val_accuracy: 0.9127
# Epoch 174/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1820 - accuracy: 0.9321 - val_loss: 0.2484 - val_accuracy: 0.9125
# Epoch 175/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1796 - accuracy: 0.9331 - val_loss: 0.2437 - val_accuracy: 0.9147
# Epoch 176/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1772 - accuracy: 0.9327 - val_loss: 0.2496 - val_accuracy: 0.9137
# Epoch 177/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1795 - accuracy: 0.9313 - val_loss: 0.2536 - val_accuracy: 0.9124
# Epoch 178/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1859 - accuracy: 0.9304 - val_loss: 0.2481 - val_accuracy: 0.9143
# Epoch 179/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1776 - accuracy: 0.9333 - val_loss: 0.2479 - val_accuracy: 0.9121
# Epoch 180/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1804 - accuracy: 0.9309 - val_loss: 0.2441 - val_accuracy: 0.9151
# Epoch 181/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1768 - accuracy: 0.9333 - val_loss: 0.2490 - val_accuracy: 0.9141
# Epoch 182/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1792 - accuracy: 0.9321 - val_loss: 0.2451 - val_accuracy: 0.9142
# Epoch 183/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1752 - accuracy: 0.9341 - val_loss: 0.2556 - val_accuracy: 0.9102
# Epoch 184/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1804 - accuracy: 0.9326 - val_loss: 0.2520 - val_accuracy: 0.9124
# Epoch 185/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1829 - accuracy: 0.9315 - val_loss: 0.2482 - val_accuracy: 0.9142
# Epoch 186/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1781 - accuracy: 0.9339 - val_loss: 0.2449 - val_accuracy: 0.9143
# Epoch 187/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1791 - accuracy: 0.9340 - val_loss: 0.2463 - val_accuracy: 0.9151
# Epoch 188/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1759 - accuracy: 0.9337 - val_loss: 0.2454 - val_accuracy: 0.9145
# Epoch 189/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1764 - accuracy: 0.9330 - val_loss: 0.2497 - val_accuracy: 0.9122
# Epoch 190/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1757 - accuracy: 0.9325 - val_loss: 0.2449 - val_accuracy: 0.9148
# Epoch 191/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1720 - accuracy: 0.9356 - val_loss: 0.2517 - val_accuracy: 0.9118
# Epoch 192/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1824 - accuracy: 0.9327 - val_loss: 0.2477 - val_accuracy: 0.9126
# Epoch 193/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1781 - accuracy: 0.9323 - val_loss: 0.2509 - val_accuracy: 0.9136
# Epoch 194/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1773 - accuracy: 0.9324 - val_loss: 0.2502 - val_accuracy: 0.9131
# Epoch 195/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1778 - accuracy: 0.9345 - val_loss: 0.2461 - val_accuracy: 0.9122
# Epoch 196/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1761 - accuracy: 0.9333 - val_loss: 0.2463 - val_accuracy: 0.9114
# Epoch 197/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1740 - accuracy: 0.9347 - val_loss: 0.2471 - val_accuracy: 0.9141
# Epoch 198/200
# 48000/48000 [==============================] - 3s 62us/step - loss: 0.1745 - accuracy: 0.9339 - val_loss: 0.2507 - val_accuracy: 0.9128
# Epoch 199/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1744 - accuracy: 0.9326 - val_loss: 0.2525 - val_accuracy: 0.9122
# Epoch 200/200
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.1751 - accuracy: 0.9341 - val_loss: 0.2574 - val_accuracy: 0.9109

# %%
#VIsualizing the training performance
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_loss'], label='val_Loss')
plt.legend()
plt.title('Loss evolution')

plt.subplot(2, 2, 2)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.title('Accuracy evolution')
# Out:
# Text(0.5, 1.0, 'Accuracy evolution')

# %%
L = 7
W = 7
fig, axes = plt.subplots(L, W, figsize = (18,18))
axes = axes.ravel()

for i in np.arange(0, L * W):  
    axes[i].imshow(X_test[i].reshape(28,28))
    axes[i].set_title(f"Prediction Class = {predicted_classes[i]:0.1f}\n True Class = {y_test[i]:0.1f}")
    axes[i].axis('off')
plt.subplots_adjust(wspace=0.5)

# %%
from sklearn.metrics import confusion_matrix
from sklearn import metrics
cm = metrics.confusion_matrix(y_test, predicted_classes)

# %%
#Defining function for confusion matrix plot
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):

    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
#     print(cm)

    fig, ax = plt.subplots(figsize=(10,10))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
plt.figure(figsize = (20,20))
plot_confusion_matrix(y_test, predicted_classes, classes=class_names, title='Non Normalized Confusion matrix')
plt.axis('off')
# Out:
# Confusion matrix, without normalization
# (-0.5, 9.5, 9.5, -0.5)

# %%
plt.figure(figsize = (20,20))
plot_confusion_matrix(y_test, predicted_classes, classes=class_names, normalize=True, title='Normalized Confusion matrix')
plt.axis('off')
# Out:
# Normalized confusion matrix
# (-0.5, 9.5, 9.5, -0.5)
